# %%
#!pip install sodapy

# %%
import sys
import types
import pandas as pd
import numpy as np

#Define which dataframes to save
saveDFList = {'dfSN', \
              'dff'
             }

#------------ IBM DSX Specific -------------
#from botocore.client import Config
#import ibm_boto3
#
#def __iter__(self): return 0
#
## @hidden_cell
## The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
## You might want to remove those credentials before you share your notebook.
#client_e0d982f9f7984059b4c6b128d1814552 = ibm_boto3.client(service_name='s3',
#    ibm_api_key_id='PkAbaFpfA7qkLJYNcF1OasbQWapxuH6P-vycQqiofFvK',
#    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
#    config=Config(signature_version='oauth'),
#    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')
#
#body = client_e0d982f9f7984059b4c6b128d1814552.get_object(Bucket='cnn-donotdelete-pr-4iz30eoowmkw91',Key='Iowa_Liquor_Sales.csv')['Body']
## add missing __iter__ method, so pandas accepts body as file-like object
#if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )
#
#dfs = pd.read_csv(body)

# Loading the shortened file into panda dataframe
fileLoc = "../data/enriched_liqSales.csv"
dfs = pd.read_csv(fileLoc)

# Transforming sales to float
#dfs['Sale (Dollars)'] = dfs['Sale (Dollars)'].str.replace('$', '')
#dfs['Sale (Dollars)'] = dfs['Sale (Dollars)'].astype(float)

#list(dfs)

dfs.dtypes
# Out:
# Invoice/Item Number       object
# Date                      object
# Store Number               int64
# Store Name                object
# Address                   object
# City                      object
# Zip Code                  object
# Store Location            object
# County Number            float64
# County                    object
# Category                 float64
# Category Name             object
# Vendor Number            float64
# Vendor Name               object
# Item Number                int64
# Item Description          object
# Pack                       int64
# Bottle Volume (ml)         int64
# State Bottle Cost         object
# State Bottle Retail       object
# Bottles Sold               int64
# Sale (Dollars)            object
# Volume Sold (Liters)     float64
# Volume Sold (Gallons)    float64
# dtype: object

# %%
#Creating a smaller sample for laptop
dfs = dfs[:2000]

#Get all HiVee records as they are the dominant brand from # of transactions
dfHiVee = dfs[dfs['Store Name'].str.contains("Hy-Vee")]
dfHiVee.sort_values(by=['Invoice/Item Number'], inplace=True, ascending=False)

#dfHiVee = dfHiVee.groupby(['Store Name'], as_index=False).agg({'Invoice/Item Number': 'count'})
#dfHiVee
#dfsn.dtypes
#list(dfsa)
#dfsn.sort(['Sale (Dollars)'], ascending=[1, 0])
# Out:
# /home/bhan/src/anaconda/anaconda2/envs/kerasJupyter/lib/python2.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
dfHiVee
# Out:
#      Invoice/Item Number        Date  Store Number  \
# 860         S29353700118  11/30/2015          2588
# 8           S29339300091  11/30/2015          2662
# 1865        S29336600009  11/30/2015          2573
# 622         S29323600006  11/30/2015          2517
# 21          S29282800048  11/23/2015          2642
# 886         S29270300006  11/23/2015          2576
# 84          S29249700269  11/21/2015          2619
# 1892        S29249700001  11/21/2015          2619
# 62          S29216200002  11/20/2015          2573
# 1560        S29206600212  11/20/2015          2506
# 23          S29199600001  11/20/2015          2558
# 65          S29199500001  11/20/2015          2555
# 51          S29199400001  11/21/2015          2544
# 44          S29199300001  11/20/2015          2539
# 1801  Hy-Vee Wine and Spirits / Bettendorf      2890 DEVILS GLEN ROAD
# 1782            Hy-Vee Wine and Spirits #2         3301 W KIMBERLY RD
# 275            Hy-Vee Drugtown / Urbandale               8601 DOUGLAS
# 1655        Hy-Vee Food and Drug / Clinton           901 SOUTH 4TH ST
#
#                  City Zip Code  \
# 860      CEDAR RAPIDS    52403
# 8           MUSCATINE    52761
# 1865        MUSCATINE    52761
# 622            NEWTON    50208
# 21              PELLA    50219
# 886        STORM LAKE    50588
# 84    WEST DES MOINES    50266
# 1892  WEST DES MOINES    50266
# 62          MUSCATINE    52761
# 1560       BURLINGTON    52601
# 23     MOUNT PLEASANT    52641
# 65             KEOKUK    52632
# 51       MARSHALLTOWN    50158
# 44         IOWA FALLS    50126
# 67    WEST DES MOINES    50265
# 92       CEDAR RAPIDS    52404
# 91             WAUKEE    50263
# 97             HARLAN    51537
# 63    WEST DES MOINES    50265
# 41         SHENANDOAH    51601
# 17            DENISON    51442
# 49           ATLANTIC    50022
# 87         MASON CITY    50401
# 80        CEDAR FALLS    50613
# 68        ESTHERVILLE    51334
# 33       CEDAR RAPIDS    52404
# 78           WATERLOO    50702
# 88            RED OAK    51566
# 71            ALTOONA    50009
# 52          IOWA CITY    52240
# ...               ...      ...
# 1886  WEST DES MOINES    50265
# 1571        MUSCATINE    52761
# 689           ALTOONA    50009
# 1269          OTTUWMA    52501
# 1077          OTTUWMA    52501
# 1661       STORM LAKE    50588
# 1668        DAVENPORT    52804
# 1009       MASON CITY    50401
# 326         IOWA CITY    52240
# 1579  WEST DES MOINES    50265
# 1694       CORALVILLE    52241
# 1906        DAVENPORT    52804
# 1144           ALGONA    50511
# 359           SHELDON    51201
# 1170        DAVENPORT    52807
# 1778        DAVENPORT    52807
# 727            LEMARS    51031
# 1516       CORALVILLE    52241
# 1908     CEDAR RAPIDS    52402
# 864      CEDAR RAPIDS    52404
# 1759       SIOUX CITY    51106
# 619           DUBUQUE    52001
# 907    COUNCIL BLUFFS    51503
# 260      CEDAR RAPIDS    52402
# 1116      CENTERVILLE    52544
# 1733     WEBSTER CITY    50595
# 1801       BETTENDORF    52722
# 1782        DAVENPORT    52804
# 275         URBANDALE    50322
# 1655          CLINTON    52732
#
#                                          Store Location  County Number  \
# 860   4035 MT. VERNON ROAD S.E.\nCEDAR RAPIDS 52403\...           57.0
# 8              522 MULBERRY, SUITE A\nMUSCATINE 52761\n           70.0
# 1865  2400 2ND AVE\nMUSCATINE 52761\n(41.45135, -91....           70.0
# 622   1501 FIRST AVENUE EAST\nNEWTON 50208\n(41.6991...           50.0
# 21    512 E OSKALOOSA\nPELLA 50219\n(41.397023, -92....           63.0
# 886   1250 N LAKE ST\nSTORM LAKE 50588\n(42.653594, ...           11.0
# 84    1725 74TH ST\nWEST DES MOINES 50266\n(41.59851...           77.0
# 1892  1725 74TH ST\nWEST DES MOINES 50266\n(41.59851...           77.0
# 62    2400 2ND AVE\nMUSCATINE 52761\n(41.45135, -91....           70.0
# 1655       Jose Cuervo Especial Reposado Flask    24                375
#
#       State Bottle Cost State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 860               $8.25              $12.38             6          $74.28
# 8                $19.58              $29.37             4         $117.48
# 1865             $49.99              $74.99             1          $74.99
# 622              $11.75              $17.63            12         $211.56
# 21               $11.62              $17.43             6         $104.58
# 886              $15.75              $23.63             2          $47.26
# 84               $99.00             $148.50             2         $297.00
# 1892             $29.72              $44.58            12         $534.96
# 62               $99.00             $148.50             2         $297.00
# 1560             $29.67              $44.51            30        $1335.30
# 23               $18.09              $27.14            18         $488.52
# 65               $18.09              $27.14             6         $162.84
# 51               $18.09              $27.14             6         $162.84
# 44               $18.09              $27.14            12         $325.68
# 67               $18.09              $27.14            24         $651.36
# 92               $18.09              $27.14             6         $162.84
# 91               $18.09              $27.14            12         $325.68
# 97               $18.09              $27.14             6         $162.84
# 63               $18.09              $27.14            48        $1302.72
# 41               $18.09              $27.14            30         $814.20
# 17               $18.09              $27.14             6         $162.84
# 49               $18.09              $27.14            24         $651.36
# 87               $18.09              $27.14            60        $1628.40
# 80               $18.09              $27.14            60        $1628.40
# 68               $18.09              $27.14            12         $325.68
# 33               $18.09              $27.14            90        $2442.60
# 78               $18.09              $27.14            24         $651.36
# 88               $18.09              $27.14            12         $325.68
# 71               $35.55              $53.34             3         $160.02
# 52               $99.00             $148.50             1         $148.50
# ...                 ...                 ...           ...             ...
# 1886             $10.49              $15.74            12         $188.88
# 1571              $7.36              $11.04             6          $66.24
# 689               $7.49              $11.23             3          $33.69
# 1269              $6.63               $9.94             5          $49.70
# 1077             $14.89              $22.34             7         $156.38
# 1661              $7.13              $10.70            18         $192.60
# 1668             $16.47              $24.70            12         $296.40
# 1009             $14.17              $21.25             2          $42.50
# 326              $10.06              $15.09             6          $90.54
# 1579              $6.30               $9.45            12         $113.40
# 1694             $15.60              $23.39             6         $140.34
# 1906              $6.49               $9.74             6          $58.44
# 1144             $12.50              $18.75            12         $225.00
# 359              $24.30              $36.44             3         $109.32
# 1170             $17.97              $26.96             3          $80.88
# 1778             $18.08              $27.13             6         $162.78
# 727               $1.51               $2.27            12          $27.24
# 1516              $6.30               $9.45            12         $113.40
# 1908             $10.49              $15.74             6          $94.44
# 864               $7.14              $10.70            12         $128.40
# 1759             $14.98              $22.47             1          $22.47
# 619              $10.41              $15.62             2          $31.24
# 907               $7.53              $11.30            12         $135.60
# 260              $18.08              $27.13             6         $162.78
# 1116              $8.99              $13.49             6          $80.94
# 1733             $13.98              $20.97             6         $125.82
# 1801              $3.64               $5.45            12          $65.40
# 1782              $7.59              $11.56             2          $23.12
# 275               $8.40              $12.59             4          $50.36
# 1655              $5.49               $8.24             3          $24.72
#
#      Volume Sold (Liters) Volume Sold (Gallons)
# 860                  4.50                  1.19
# 8                    3.00                  0.79
# 1865                 0.75                  0.20
# 622                 12.00                  3.17
# 21                   9.00                  2.38
# 886                  3.50                  0.92
# 84                  12.00                  3.17
# 1892                36.00                  9.51
# 62                  12.00                  3.17
# 1560                52.50                 13.87
# 23                  13.50                  3.57
# 65                   4.50                  1.19
# 51                   4.50                  1.19
# 44                   9.00                  2.38
# 67                  18.00                  4.76
# 92                   4.50                  1.19
# 91                   9.00                  2.38
# 97                   4.50                  1.19
# 63                  36.00                  9.51
# 41                  22.50                  5.94
# 17                   4.50                  1.19
# 49                  18.00                  4.76
# 87                  45.00                 11.89
# 80                  45.00                 11.89
# 68                   9.00                  2.38
# 33                  67.50                 17.83
# 78                  18.00                  4.76
# 88                   9.00                  2.38
# 71                   5.25                  1.39
# 52                   6.00                  1.59
# ...                   ...                   ...
# 1886                 9.00                  2.38
# 1571                10.50                  2.77
# 689                  2.25                  0.59
# 1269                 5.00                  1.32
# 1077                 7.00                  1.85
# 1661                31.50                  8.32
# 1668                12.00                  3.17
# 1009                 1.50                  0.40
# 326                 10.50                  2.77
# 1579                 9.00                  2.38
# 1694                 4.50                  1.19
# 1906                10.50                  2.77
# 1144                 9.00                  2.38
# 359                  2.25                  0.59
# 1170                 2.25                  0.59
# 1778                 4.50                  1.19
# 727                  1.20                  0.32
# 1516                 9.00                  2.38
# 1908                10.50                  2.77
# 864                 21.00                  5.55
# 1759                 1.00                  0.26
# 619                  1.50                  0.40
# 907                  9.00                  2.38
# 260                  4.50                  1.19
# 1116                10.50                  2.77
# 1733                10.50                  2.77
# 1801                 9.00                  2.38
# 1782                 1.50                  0.40
# 275                  3.00                  0.79
# 1655                 1.12                  0.30
#
# [682 rows x 24 columns]

# %%
class builddf:
    def __init__(self,name = None):
        self.name = name # array of column names to encode
        dfsa[name] =  
        
new_df = dfsa['Store Name'].apply(lambda x: callFunc(name=x))
new_df

#Iterate and build the dataframes for top vendors
#Get all top mm profit storeNames for which we will filter on dfsModel
#dfsTopMMP = dfsModel.loc[dfsModel['monthlyProfit']>0].drop(['year','month','monthlyProfit'], axis=1)

#Filter down dfsModel to top profit stores
#dfsModel = dfsModel[dfsModel['latlong'].isin(dfsTopMMP['latlong'].values)]
# Out:
# 249           Hy-Vee #3 / BDI / Des Moines
# 355    Hy-Vee Wine and Spirits / Iowa City
# 727                         Wilkie Liquors
# 91               Central City Liquor, Inc.
# 342             Hy-Vee Wine and Spirits #2
# 305        Hy-Vee Food Store / Cedar Falls
# 283      Hy-Vee Food Store #1 / Mason City
# 253                        Hy-Vee #4 / WDM
# 245              Hy-Vee #1044 / Burlington
# 90                          Central City 2
# Name: Store Name, dtype: object

# %%
#---- IBM DSX specific ----
#credentials = {
#    'IBM_API_KEY_ID': 'PkAbaFpfA7qkLJYNcF1OasbQWapxuH6P-vycQqiofFvK',
#    'IAM_SERVICE_ID': 'iam-ServiceId-a42a0a9d-b15f-482d-8ad4-7f333af35771',
#    'ENDPOINT': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
#    'IBM_AUTH_ENDPOINT': 'https://iam.ng.bluemix.net/oidc/token',
#    'BUCKET': 'cnn-donotdelete-pr-4iz30eoowmkw91',
#    'FILE': 'liqSales.csv'
#}
#
##Save to csv file at object storage
#cos = ibm_boto3.client(service_name='s3',
#    ibm_api_key_id=credentials['IBM_API_KEY_ID'],
#    ibm_service_instance_id=credentials['IAM_SERVICE_ID'],
#    ibm_auth_endpoint=credentials['IBM_AUTH_ENDPOINT'],
#    config=Config(signature_version='oauth'),
#    endpoint_url=credentials['ENDPOINT'])
#
## Build the enriched file name from the original filename.
#localfilename = 'sNCount_' + credentials['FILE']
#
## Write a CSV file from the enriched pandas DataFrame.
#dff.to_csv(localfilename, index=False)
#
## Use the above put_file method with credentials to put the file in Object Storage.
#cos.upload_file(localfilename, Bucket=credentials['BUCKET'],Key=localfilename)

# %%
#Rename Fields to simplify using the df
#dfs.rename(columns={'Date': 'date'}, inplace=True)
#dfs.rename(columns={'Store Number': 'storeNum'}, inplace=True)
#dfs.rename(columns={'Store Name': 'storeName'}, inplace=True)
#dfs.rename(columns={'Zip Code': 'zip'}, inplace=True)
#dfs.rename(columns={'Store Location': 'storeLocation'}, inplace=True)

# %%
#Drop categorical data for now
#dfs = dfs.drop(columns=['Invoice/Item Number','date','County Number','County','Category','Category Name', 'Vendor Number','Vendor Name','Item Number','Item Description','Pack','Bottle Volume (ml)','State Bottle Cost','State Bottle Retail','Bottles Sold','Sale (Dollars)','Volume Sold (Liters)','Volume Sold (Gallons)'])
#dfs.dtypes
# Out:
# storeNum          int64
# storeName        object
# Address          object
# City             object
# zip              object
# storeLocation    object
# dtype: object

# %%
#dfs['latlong'] = dfs['storeLocation'].str.extract('((?<=\().*?(?=\)))', expand=True)

# %%
#dff=dfs.groupby(['storeName', 'latlong', 'Address','City','zip']).size() \
#      .sort_values(ascending=False) \
#      .reset_index(name='count') \
#      .drop_duplicates(subset='latlong')
#dff

# %%
#---- IBM DSX specific ----
#credentials = {
#    'IBM_API_KEY_ID': 'PkAbaFpfA7qkLJYNcF1OasbQWapxuH6P-vycQqiofFvK',
#    'IAM_SERVICE_ID': 'iam-ServiceId-a42a0a9d-b15f-482d-8ad4-7f333af35771',
#    'ENDPOINT': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
#    'IBM_AUTH_ENDPOINT': 'https://iam.ng.bluemix.net/oidc/token',
#    'BUCKET': 'cnn-donotdelete-pr-4iz30eoowmkw91',
#    'FILE': 'liqSales.csv'
#}
#
##Save to csv file at object storage
#cos = ibm_boto3.client(service_name='s3',
#    ibm_api_key_id=credentials['IBM_API_KEY_ID'],
#    ibm_service_instance_id=credentials['IAM_SERVICE_ID'],
#    ibm_auth_endpoint=credentials['IBM_AUTH_ENDPOINT'],
#    config=Config(signature_version='oauth'),
#    endpoint_url=credentials['ENDPOINT'])
#
## Build the enriched file name from the original filename.
#localfilename = 'XY_' + credentials['FILE']
#
## Write a CSV file from the enriched pandas DataFrame.
#dff.to_csv(localfilename, index=False)
#
## Use the above put_file method with credentials to put the file in Object Storage.
#cos.upload_file(localfilename, Bucket=credentials['BUCKET'],Key=localfilename)
