# %%
#!pip install sodapy

# %%
import sys
import types
import pandas as pd

#Define which dataframes to save
saveDFList = {'dfSN', \
              'dff'
             }

#------------ IBM DSX Specific -------------
#from botocore.client import Config
#import ibm_boto3
#
#def __iter__(self): return 0
#
## @hidden_cell
## The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
## You might want to remove those credentials before you share your notebook.
#client_e0d982f9f7984059b4c6b128d1814552 = ibm_boto3.client(service_name='s3',
#    ibm_api_key_id='PkAbaFpfA7qkLJYNcF1OasbQWapxuH6P-vycQqiofFvK',
#    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
#    config=Config(signature_version='oauth'),
#    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')
#
#body = client_e0d982f9f7984059b4c6b128d1814552.get_object(Bucket='cnn-donotdelete-pr-4iz30eoowmkw91',Key='Iowa_Liquor_Sales.csv')['Body']
## add missing __iter__ method, so pandas accepts body as file-like object
#if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )
#
#dfs = pd.read_csv(body)

# Loading the shortened file into panda dataframe
fileLoc = "../data/enriched_liqSales.csv"
dfs = pd.read_csv(fileLoc)

# Transforming sales to float
dfs['Sale (Dollars)'] = dfs['Sale (Dollars)'].str.replace('$', '')
dfs['Sale (Dollars)'] = dfs['Sale (Dollars)'].astype(float)

list(dfs)

dfs.dtypes
# Out:
# Invoice/Item Number       object
# Date                      object
# Store Number               int64
# Store Name                object
# Address                   object
# City                      object
# Zip Code                  object
# Store Location            object
# County Number            float64
# County                    object
# Category                 float64
# Category Name             object
# Vendor Number            float64
# Vendor Name               object
# Item Number                int64
# Item Description          object
# Pack                       int64
# Bottle Volume (ml)         int64
# State Bottle Cost         object
# State Bottle Retail       object
# Bottles Sold               int64
# Sale (Dollars)           float64
# Volume Sold (Liters)     float64
# Volume Sold (Gallons)    float64
# dtype: object

# %%
#Get count of transactions by store name
dfsn = dfs.groupby(['Store Name'])['Sale (Dollars)'].sum().sort_values(ascending=False)
cred
#dfsn.sort_values(by='0', ascending=True)
#dfsn.dtypes
#list(dfsn)
#dfsn.sort(['Sale (Dollars)'], ascending=[1, 0])
# Out:
# [6825787.670000007,
#  4244039.789999953,
#  2865029.059999991,
#  2786740.839999983,
#  2674887.0099999276,
#  2392080.8899999904,
#  2107708.0899999673,
#  1942386.159999929,
#  1815011.0299999844,
#  1511743.379999976,
#  1501751.3099999859,
#  1454509.0899999742,
#  1356074.539999997,
#  1325698.9799999956,
#  1212015.8399999896,
#  1195243.6499999915,
#  1177768.529999994,
#  1170357.0199999986,
#  1120686.5299999923,
#  1078484.2199999993,
#  1076345.2299999997,
#  1072754.0099999872,
#  1068245.099999994,
#  1003525.9599999964,
#  982195.0499999853,
#  959935.2799999906,
#  948889.2299999896,
#  934372.1099999954,
#  920842.519999999,
#  898865.400000001,
#  886417.1699999996,
#  862641.7900000003,
#  853053.0400000017,
#  851712.5799999952,
#  850256.0399999999,
#  839003.5000000055,
#  830277.8899999979,
#  825789.8700000002,
#  818859.449999996,
#  ...]

# %%
#dfsn
# Out:
# Store Name
# 218 Fuel Express & Chubby's Liquor        49873.82
# 3rd St Convenience                        37706.02
# 7 Rayos Liquor Store                     296040.69
# A J'S LIQUOR II                          379991.45
# A To Z Liquor and Smoke Shop             122728.53
# A to Z Liquor                             23141.82
# A-TOWN LIQUOR STORE                       71829.16
# A. V. Liquor                               5088.54
# AJ's Liquor III                           27629.93
# ATC Liquor                               206103.94
# AV Superstop                               2761.44
# Abby Lea's                                24403.41
# Ackley Super Foods                        14827.50
# Adventureland Inn                         63591.72
# Afal Food & Liquor / Des Moines            2114.69
# Affiliated Foods Of Manson                49813.45
# After 5 Somewhere                        101214.48
# Aj's Liquor / Ames                       116905.31
# Al's Liquors Unlimited                   389708.58
# Ali's Corner #2                            4507.44
# Ali's Liquor                              71861.73
# Ali's West Side Liquor                    70577.34
# Almost Always Open                        11046.85
# Ameristar Casino / Council Bluffs        259521.05
# Ameristar Casino Council Bluffs Gift        558.35
# Anamosa Family Foods                     289351.34
# Armstrong Liquor Store                    17292.43
# Audubon Food Land                          6437.51
# Audubon Food Pride                        88036.21
# Avoca Liquor                             227539.13
#                                            ...
# Walgreens #11710 / North Liberty          13876.75
# Walgreens #11759 / Fort Madison            9565.32
# Walgreens #11942 / Dubuque                21970.55
# Walgreens #12108 / Ames                   20308.50
# Walgreens #12148 / Waverly                13127.40
# Walgreens #12393 / Cedar Rapids           17325.36
# Walgreens #12580 / Cedar Rapids           19617.79
# Walgreens #15647 / Sioux City             10623.94
# Wapello Jack and Jill                     43489.91
# Washington Street Mini Mart              246375.41
# West K Mart                                6536.39
# West Side Liquor / Waterloo               35021.44
# West Side Spirits                         64836.13
# Westland Fast Break                        9161.81
# Wheatland Day Break                        6601.14
# Wild Rose Emmetsburg, Llc                 45076.37
# Wilkie Liquors                          1454509.09
# Williams Boulevard Service, Inc.          12827.16
# Williamsburg Foods                        86261.33
# Wilton Express                             4535.06
# Wine and Spirits Gallery                 211397.09
# Wine and Spirits Shoppe Of               186068.11
# Wines and Spirits                        365545.56
# Wj's Liquor                               64339.39
# World Liquor & Tobacco                    95214.76
# Xo Food And Liquor                       126113.79
# Xpress Liquor                              6784.77
# Yr Dollar Stop                            26608.97
# Z's Quickbreak                            37312.70
# Zapf's Pronto Market                      16331.17
# Name: Sale (Dollars), Length: 1534, dtype: float64

# %%
#Write the csv

# %%
#---- IBM DSX specific ----
#credentials = {
#    'IBM_API_KEY_ID': 'PkAbaFpfA7qkLJYNcF1OasbQWapxuH6P-vycQqiofFvK',
#    'IAM_SERVICE_ID': 'iam-ServiceId-a42a0a9d-b15f-482d-8ad4-7f333af35771',
#    'ENDPOINT': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
#    'IBM_AUTH_ENDPOINT': 'https://iam.ng.bluemix.net/oidc/token',
#    'BUCKET': 'cnn-donotdelete-pr-4iz30eoowmkw91',
#    'FILE': 'liqSales.csv'
#}
#
##Save to csv file at object storage
#cos = ibm_boto3.client(service_name='s3',
#    ibm_api_key_id=credentials['IBM_API_KEY_ID'],
#    ibm_service_instance_id=credentials['IAM_SERVICE_ID'],
#    ibm_auth_endpoint=credentials['IBM_AUTH_ENDPOINT'],
#    config=Config(signature_version='oauth'),
#    endpoint_url=credentials['ENDPOINT'])
#
## Build the enriched file name from the original filename.
#localfilename = 'sNCount_' + credentials['FILE']
#
## Write a CSV file from the enriched pandas DataFrame.
#dff.to_csv(localfilename, index=False)
#
## Use the above put_file method with credentials to put the file in Object Storage.
#cos.upload_file(localfilename, Bucket=credentials['BUCKET'],Key=localfilename)

# %%
#Rename Fields to simplify using the df
#dfs.rename(columns={'Date': 'date'}, inplace=True)
#dfs.rename(columns={'Store Number': 'storeNum'}, inplace=True)
#dfs.rename(columns={'Store Name': 'storeName'}, inplace=True)
#dfs.rename(columns={'Zip Code': 'zip'}, inplace=True)
#dfs.rename(columns={'Store Location': 'storeLocation'}, inplace=True)

# %%
#Drop categorical data for now
#dfs = dfs.drop(columns=['Invoice/Item Number','date','County Number','County','Category','Category Name', 'Vendor Number','Vendor Name','Item Number','Item Description','Pack','Bottle Volume (ml)','State Bottle Cost','State Bottle Retail','Bottles Sold','Sale (Dollars)','Volume Sold (Liters)','Volume Sold (Gallons)'])
#dfs.dtypes
# Out:
# storeNum          int64
# storeName        object
# Address          object
# City             object
# zip              object
# storeLocation    object
# dtype: object

# %%
#dfs['latlong'] = dfs['storeLocation'].str.extract('((?<=\().*?(?=\)))', expand=True)

# %%
#dff=dfs.groupby(['storeName', 'latlong', 'Address','City','zip']).size() \
#      .sort_values(ascending=False) \
#      .reset_index(name='count') \
#      .drop_duplicates(subset='latlong')
#dff

# %%
#---- IBM DSX specific ----
#credentials = {
#    'IBM_API_KEY_ID': 'PkAbaFpfA7qkLJYNcF1OasbQWapxuH6P-vycQqiofFvK',
#    'IAM_SERVICE_ID': 'iam-ServiceId-a42a0a9d-b15f-482d-8ad4-7f333af35771',
#    'ENDPOINT': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
#    'IBM_AUTH_ENDPOINT': 'https://iam.ng.bluemix.net/oidc/token',
#    'BUCKET': 'cnn-donotdelete-pr-4iz30eoowmkw91',
#    'FILE': 'liqSales.csv'
#}
#
##Save to csv file at object storage
#cos = ibm_boto3.client(service_name='s3',
#    ibm_api_key_id=credentials['IBM_API_KEY_ID'],
#    ibm_service_instance_id=credentials['IAM_SERVICE_ID'],
#    ibm_auth_endpoint=credentials['IBM_AUTH_ENDPOINT'],
#    config=Config(signature_version='oauth'),
#    endpoint_url=credentials['ENDPOINT'])
#
## Build the enriched file name from the original filename.
#localfilename = 'XY_' + credentials['FILE']
#
## Write a CSV file from the enriched pandas DataFrame.
#dff.to_csv(localfilename, index=False)
#
## Use the above put_file method with credentials to put the file in Object Storage.
#cos.upload_file(localfilename, Bucket=credentials['BUCKET'],Key=localfilename)
